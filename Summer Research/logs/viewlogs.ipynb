# %%
from pathlib import Path
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
cwd = Path.cwd()

# %%
df = pd.read_json('fc_log.json')
df[['completeness (dusty)', 'purity (dusty)', 'accuracy', 'scale', 'comment']]
# Out:
#     completeness (dusty)  purity (dusty)  accuracy  scale  \
# 0                0.62500        0.425532  0.593750     32
# 1                0.62500        0.425532  0.593750     32
# 2                0.62500        0.434783  0.604167     32
# 3                0.68750        0.431373  0.593750     32
# 4                0.03125        0.333333  0.656250     32
# 5                0.62500        0.434783  0.604167     32
# 6                0.21875        0.583333  0.687500     32
# 7                0.21875        0.583333  0.687500     32
# 8                0.21875        0.583333  0.687500     32
# 9                    NaN             NaN  0.666667      8
# 10                   NaN             NaN  0.666667      8
# 11               0.03125        1.000000  0.677083     16
# 12               0.34375        0.611111  0.705263     16
# 13               0.53125        0.485714  0.652632      8
# 14               0.50000        0.484848  0.652632     32
# 15               0.50000        0.516129  0.673684      8
# 16               0.15625        0.416667  0.642105     16
# 17               0.00000        0.000000  0.631579     16
# 18               0.03125        0.200000  0.631579     16
# 19               0.43750        0.500000  0.663158     32
# 20               0.53125        0.515152  0.673684     64
# 21               0.53125        0.500000  0.663158     64
# 22               0.34375        0.523810  0.673684     64
# 23               0.46875        0.500000  0.663158     64
# 24               0.56250        0.529412  0.684211     64
# 25               0.50000        0.484848  0.652632     64
# 26               0.59375        0.487179  0.652632     64
# 27               0.50000        0.444444  0.621053     64
# 28               0.43750        0.500000  0.663158     16
# 29               0.50000        0.516129  0.673684      8
# 30               0.65625        0.512195  0.673684      8
# 31               0.56250        0.545455  0.694737      8
# 32               0.53125        0.472222  0.642105      4
#
#                                          comment
# 0                                           test
# 1                                           test
# 2                                 batch size 128
# 3                                 batch size 256
# 4                                  batch size 16
# 5                                           test
# 6                             incrase num epochs
# 7                            decrease model size
# 8
# 9                              reduce model size
# 10
# 11    increase model size - only predicted flase
# 12                                 add beta mask
# 13                  small model with masked beta
# 14                                  larger model
# 15                                        add av
# 16               increase model size and dropout
# 17                              increase dropout
# 18                                reduce dropout
# 19                           increase model size
# 20  fix masking issue for bad av and beta values
# 21                              increase dropout
# 22                increase dropout - overfitting
# 23                               increase epochs
# 24                               try low dropout
# 25                        decrease learning rate
# 26       reset learning rate and increase epochs
# 27                              try lr scheduler
# 28          decrease size num epochs and dropout
# 29                                 decrease size
# 30                               increase epochs
# 31                               increase epochs
# 32                                 decrease size

# %%
df
# Out:
#     num_outputs  input_dim  fc_dim  dropout  scale  \
# 0             2          1   128.0      0.4     32
# 1             2          1   128.0      0.4     32
# 2             2          1   128.0      0.4     32
# 3             2          1   128.0      0.4     32
# 4             2          1   128.0      0.4     32
# 5             2          1   128.0      0.4     32
# 6             2          1   128.0      0.4     32
# 7             2          1    32.0      0.4     32
# 8             2          1    16.0      0.4     32
# 9             2          1     NaN      0.2      8
# 10            2          1     NaN      0.2      8
# 11            2          1     NaN      0.2     16
# 12            2          1     NaN      0.2     16
# 13            2          1     NaN      0.2      8
# 14            2          1     NaN      0.2     32
# 15            2          2     NaN      0.2      8
# 16            2          2     NaN      0.3     16
# 17            2          2     NaN      0.5     16
# 18            2          2     NaN      0.4     16
# 19            2          2     NaN      0.4     32
# 20            2          2     NaN      0.4     64
# 21            2          2     NaN      0.5     64
# 22            2          2     NaN      0.6     64
# 23            2          2     NaN      0.6     64
# 24            2          2     NaN      0.3     64
# 25            2          2     NaN      0.3     64
# 26            2          2     NaN      0.3     64
# 27            2          2     NaN      0.3     64
# 28            2          2     NaN      0.2     16
# 29            2          2     NaN      0.2      8
# 30            2          2     NaN      0.2      8
# 31            2          2     NaN      0.2      8
# 32            2          2     NaN      0.2      4
#
#                                          comment  seed  batch size  epochs  \
# 0                                           test    42          64    1000
# 1                                           test    42          64    1000
# 2                                 batch size 128    42         128    1000
# 3                                 batch size 256    42         256    1000
# 4                                  batch size 16    42          16    1000
# 5                                           test    42         128    1000
# 6                             incrase num epochs    42         128    2000
# 7                            decrease model size    42         128    2000
# 8                                                   42         128    2000
# 9                              reduce model size    42         128    2000
# 10                                                  42         128    4000
# 11    increase model size - only predicted flase    42         128    4000
# 12                                 add beta mask    42         128    4000
# 13                  small model with masked beta    42         128    4000
# 14                                  larger model    42         128    4000
# 15                                        add av    42         128    4000
# 16               increase model size and dropout    42         128    4000
# 17                              increase dropout    42         128    4000
# 18                                reduce dropout    42         128    4000
# 19                           increase model size    42         128    4000
# 20  fix masking issue for bad av and beta values    42         128    4000
# 21                              increase dropout    42         128    4000
# 22                increase dropout - overfitting    42         128    4000
# 23                               increase epochs    42         128    8000
# 24                               try low dropout    42         128    8000
# 25                        decrease learning rate    42         128    8000
# 26       reset learning rate and increase epochs    42         128   16000
# 27                              try lr scheduler    42         128   16000
# 28          decrease size num epochs and dropout    42         128    4000
# 29                                 decrease size    42         128    4000
# 30                               increase epochs    42         128   16000
# 31                               increase epochs    42         128   32000
# 32                                 decrease size    42         128   32000
#
#     learning rate  weight decay input features output features  sample size  \
# 0         0.00010          0.01         [beta]          [flag]          486
# 1         0.00010          0.01         [beta]          [flag]          486
# 2         0.00010          0.01         [beta]          [flag]          486
# 3         0.00010          0.01         [beta]          [flag]          486
# 4         0.00010          0.01         [beta]          [flag]          486
# 5         0.00010          0.01         [beta]          [flag]          486
# 6         0.00010          0.01         [beta]          [flag]          486
# 7         0.00010          0.01         [beta]          [flag]          486
# 8         0.00010          0.01         [beta]          [flag]          486
# 9         0.00010          0.01         [beta]          [flag]          486
# 10        0.00010          0.01         [beta]          [flag]          486
# 11        0.00010          0.01         [beta]          [flag]          486
# 12        0.00010          0.01         [beta]          [flag]          481
# 13        0.00010          0.01         [beta]          [flag]          481
# 14        0.00010          0.01         [beta]          [flag]          481
# 15        0.00010          0.01     [beta, Av]          [flag]          481
# 16        0.00010          0.01     [beta, Av]          [flag]          481
# 17        0.00010          0.01     [beta, Av]          [flag]          481
# 18        0.00010          0.01     [beta, Av]          [flag]          481
# 19        0.00010          0.01     [beta, Av]          [flag]          481
# 20        0.00010          0.01     [beta, Av]          [flag]          481
# 21        0.00010          0.01     [beta, Av]          [flag]          481
# 22        0.00010          0.01     [beta, Av]          [flag]          481
# 23        0.00010          0.01     [beta, Av]          [flag]          481
# 24        0.00010          0.01     [beta, Av]          [flag]          481
# 25        0.00001          0.01     [beta, Av]          [flag]          481
# 26        0.00010          0.01     [beta, Av]          [flag]          481
# 27        0.00010          0.01     [beta, Av]          [flag]          481
# 28        0.00010          0.01     [beta, Av]          [flag]          481
# 29        0.00010          0.01     [beta, Av]          [flag]          481
# 30        0.00010          0.01     [beta, Av]          [flag]          481
# 31        0.00010          0.01     [beta, Av]          [flag]          481
# 32        0.00010          0.01     [beta, Av]          [flag]          481
#
#          loss function                                              model  \
# 0   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 1   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 2   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 3   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 4   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 5   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 6   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 7   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 8   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 9   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 10  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 11  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 12  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 13  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 14  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 15  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 16  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 17  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 18  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 19  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 20  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 21  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 22  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 23  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 24  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 25  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 26  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 27  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 28  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 29  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 30  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 31  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 32  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
#
#                                             optimizer  num params  \
# 0   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 1   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 2   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 3   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 4   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 5   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 6   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 7   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 8   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 9   AdamW (\nParameter Group 0\n    amsgrad: False...          96
# 10  AdamW (\nParameter Group 0\n    amsgrad: False...          96
# 11  AdamW (\nParameter Group 0\n    amsgrad: False...         270
# 12  AdamW (\nParameter Group 0\n    amsgrad: False...         270
# 13  AdamW (\nParameter Group 0\n    amsgrad: False...          96
# 14  AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 15  AdamW (\nParameter Group 0\n    amsgrad: False...         286
# 16  AdamW (\nParameter Group 0\n    amsgrad: False...         890
# 17  AdamW (\nParameter Group 0\n    amsgrad: False...         890
# 18  AdamW (\nParameter Group 0\n    amsgrad: False...         890
# 19  AdamW (\nParameter Group 0\n    amsgrad: False...        3058
# 20  AdamW (\nParameter Group 0\n    amsgrad: False...       11234
# 21  AdamW (\nParameter Group 0\n    amsgrad: False...       11234
# 22  AdamW (\nParameter Group 0\n    amsgrad: False...       11234
# 23  AdamW (\nParameter Group 0\n    amsgrad: False...       11234
# 24  AdamW (\nParameter Group 0\n    amsgrad: False...       11234
# 25  AdamW (\nParameter Group 0\n    amsgrad: False...       11234
# 26  AdamW (\nParameter Group 0\n    amsgrad: False...       11234
# 27  AdamW (\nParameter Group 0\n    amsgrad: False...       11234
# 28  AdamW (\nParameter Group 0\n    amsgrad: False...         890
# 29  AdamW (\nParameter Group 0\n    amsgrad: False...         286
# 30  AdamW (\nParameter Group 0\n    amsgrad: False...         286
# 31  AdamW (\nParameter Group 0\n    amsgrad: False...         286
# 32  AdamW (\nParameter Group 0\n    amsgrad: False...         104
#
#     purity (dusty)  completeness (dusty)  accuracy  \
# 0         0.425532               0.62500  0.593750
# 1         0.425532               0.62500  0.593750
# 2         0.434783               0.62500  0.604167
# 3         0.431373               0.68750  0.593750
# 4         0.333333               0.03125  0.656250
# 5         0.434783               0.62500  0.604167
# 6         0.583333               0.21875  0.687500
# 7         0.583333               0.21875  0.687500
# 8         0.583333               0.21875  0.687500
# 9              NaN                   NaN  0.666667
# 10             NaN                   NaN  0.666667
# 11        1.000000               0.03125  0.677083
# 12        0.611111               0.34375  0.705263
# 13        0.485714               0.53125  0.652632
# 14        0.484848               0.50000  0.652632
# 15        0.516129               0.50000  0.673684
# 16        0.416667               0.15625  0.642105
# 17        0.000000               0.00000  0.631579
# 18        0.200000               0.03125  0.631579
# 19        0.500000               0.43750  0.663158
# 20        0.515152               0.53125  0.673684
# 21        0.500000               0.53125  0.663158
# 22        0.523810               0.34375  0.673684
# 23        0.500000               0.46875  0.663158
# 24        0.529412               0.56250  0.684211
# 25        0.484848               0.50000  0.652632
# 26        0.487179               0.59375  0.652632
# 27        0.444444               0.50000  0.621053
# 28        0.500000               0.43750  0.663158
# 29        0.516129               0.50000  0.673684
# 30        0.512195               0.65625  0.673684
# 31        0.545455               0.56250  0.694737
# 32        0.472222               0.53125  0.642105
#
#                                      confusion matrix  last validation loss
# 0   Predicted   0   1\nActual           \n0       ...              0.830167
# 1   Predicted   0   1\nActual           \n0       ...              0.830167
# 2   Predicted   0   1\nActual           \n0       ...              0.830733
# 3   Predicted   0   1\nActual           \n0       ...              0.826692
# 4   Predicted   0  1\nActual          \n0         ...              0.831327
# 5   Predicted   0   1\nActual           \n0       ...              0.830733
# 6   Predicted   0  1\nActual          \n0         ...              0.831628
# 7   Predicted   0  1\nActual          \n0         ...              0.831628
# 8   Predicted   0  1\nActual          \n0         ...              0.831628
# 9   Predicted   0\nActual       \n0          64\n1...              0.834341
# 10  Predicted   0\nActual       \n0          64\n1...              0.832097
# 11  Predicted   0  1\nActual          \n0         ...              0.829949
# 12  Predicted   0   1\nActual           \n0       ...              0.823392
# 13  Predicted   0   1\nActual           \n0       ...              0.818544
# 14  Predicted   0   1\nActual           \n0       ...              0.817317
# 15  Predicted   0   1\nActual           \n0       ...              0.816633
# 16  Predicted   0  1\nActual          \n0         ...              0.831131
# 17  Predicted   0  1\nActual          \n0         ...              0.833554
# 18  Predicted   0  1\nActual          \n0         ...              0.833578
# 19  Predicted   0   1\nActual           \n0       ...              0.823613
# 20  Predicted   0   1\nActual           \n0       ...              0.817702
# 21  Predicted   0   1\nActual           \n0       ...              0.817321
# 22  Predicted   0   1\nActual           \n0       ...              0.825406
# 23  Predicted   0   1\nActual           \n0       ...              0.818157
# 24  Predicted   0   1\nActual           \n0       ...              0.805438
# 25  Predicted   0   1\nActual           \n0       ...              0.808208
# 26  Predicted   0   1\nActual           \n0       ...              0.806728
# 27  Predicted   0   1\nActual           \n0       ...              0.813724
# 28  Predicted   0   1\nActual           \n0       ...              0.819977
# 29  Predicted   0   1\nActual           \n0       ...              0.816633
# 30  Predicted   0   1\nActual           \n0       ...              0.801329
# 31  Predicted   0   1\nActual           \n0       ...              0.802310
# 32  Predicted   0   1\nActual           \n0       ...              0.815459
