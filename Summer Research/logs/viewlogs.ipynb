# %%
from pathlib import Path
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
cwd = Path.cwd()

# %%
df = pd.read_json('fc_log.json')
df.sort_values(by='accuracy', ascending=False).head()
# Out:
#     n_layers  n_units_l0  dropout_l0        lr optimizer  adamw_weight_decay  \
# 7          1          44    0.418882  0.003550      Adam                 NaN
# 6          1          44    0.418882  0.003550      Adam                 NaN
# 5          1          44    0.418882  0.003550      Adam                 NaN
# 4          1          44    0.418882  0.003550      Adam                 NaN
# 11         1         117    0.277634  0.004468     AdamW            0.000055
#
#           w1        w2  batch_size  accuracy             comment  \
# 7   2.426490  2.521570          32  0.723404  test seed function
# 6   2.426490  2.521570          32  0.723404  test seed function
# 5   2.426490  2.521570          32  0.723404       test for seed
# 4   2.426490  2.521570          32  0.723404            test run
# 11  2.939169  2.550266          16  0.708333        test new idx
#
#                            in_features out_features  seed  epochs  num_trials  \
# ...

# %%
df[::-1].head()
# Out:
#     n_layers  n_units_l0  dropout_l0        lr optimizer  adamw_weight_decay  \
# 11         1         117    0.277634  0.004468     AdamW            0.000055
# 10         1         117    0.277634  0.004468     AdamW            0.000055
# 9          1          42    0.357427  0.000534       SGD                 NaN
# 8          1          42    0.357427  0.000534       SGD                 NaN
# 7          1          44    0.418882  0.003550      Adam                 NaN
#
#           w1        w2  batch_size  accuracy             comment  \
# 11  2.939169  2.550266          16  0.708333        test new idx
# 10  2.939169  2.550266          16  0.708333        test new idx
# 9   1.732724  1.912140          16  0.666667        test new idx
# 8   1.732724  1.912140          16  0.666667        test new inx
# 7   2.426490  2.521570          32  0.723404  test seed function
#
#                            in_features out_features  seed  epochs  num_trials  \
# ...
