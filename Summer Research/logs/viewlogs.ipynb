# %%
from pathlib import Path
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
cwd = Path.cwd()

# %%
df = pd.read_json('fc_log.json')
df.sort_values(by='accuracy', ascending=False).head()
# Out:
#      num_outputs  input_dim  fc_dim  dropout  scale  \
# 64           2.0        NaN     NaN      0.6   32.0
# 75           2.0        NaN     NaN      0.7  256.0
# 58           2.0        NaN     NaN      0.6   32.0
# 12           2.0        1.0     NaN      0.2   16.0
# 105          2.0        6.0     NaN      0.7  256.0
#
#                           comment  seed  batch size   epochs  learning rate  \
# 64               lower batch szie  42.0        32.0   5000.0         0.0001
# 75                testing stopper  42.0        30.0  10000.0         0.0001
# 58                actually dropna  42.0       128.0   5000.0         0.0001
# 12                  add beta mask  42.0       128.0   4000.0         0.0001
# 105  after scaling - large epochs  42.0        30.0  10000.0         0.0001
#
#      weight decay                                     input features  \
# 64           0.01                 [beta, Av, F115, F150, F277, F444]
# 75           0.01  [beta, Av, F115, F150, F200, F277, F356, F410,...
# 58           0.01                 [beta, Av, F115, F150, F277, F444]
# 12           0.01                                             [beta]
# 105          0.01                 [beta, Av, F115, F150, F277, F444]
#
#     output features  sample size       loss function  \
# 64           [flag]        449.0  CrossEntropyLoss()
# 75           [flag]        440.0  CrossEntropyLoss()
# 58           [flag]        449.0  CrossEntropyLoss()
# 12           [flag]        481.0  CrossEntropyLoss()
# 105          [flag]          NaN  CrossEntropyLoss()
#
#                                                  model  \
# 64   GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 75   GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 58   GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 12   GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 105  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
#
#                                              optimizer  num params  \
# 64   AdamW (\nParameter Group 0\n    amsgrad: False...     25298.0
# 75   AdamW (\nParameter Group 0\n    amsgrad: False...     19778.0
# 58   AdamW (\nParameter Group 0\n    amsgrad: False...     25298.0
# 12   AdamW (\nParameter Group 0\n    amsgrad: False...       270.0
# 105  AdamW (\nParameter Group 0\n    amsgrad: False...     19010.0
#
#      purity (dusty)  completeness (dusty)  accuracy  \
# 64         0.642857              0.580645  0.741573
# 75         0.594595              0.709677  0.724138
# 58         0.575000              0.741935  0.719101
# 12         0.611111              0.343750  0.705263
# 105        0.545455              0.750000  0.702128
#
#                                       confusion matrix  last validation loss  \
# 64   Predicted   0   1\nActual           \n0       ...              0.788367
# 75   Predicted   0   1\nActual           \n0       ...              0.761603
# 58   Predicted   0   1\nActual           \n0       ...              0.782468
# 12   Predicted   0   1\nActual           \n0       ...              0.823392
# 105  Predicted   0   1\nActual           \n0       ...              0.803179
#
#      n_layers  n_units_l0  dropout_l0  n_units_l1  dropout_l1  lr  \
# 64        NaN         NaN         NaN         NaN         NaN NaN
# 75        NaN         NaN         NaN         NaN         NaN NaN
# 58        NaN         NaN         NaN         NaN         NaN NaN
# 12        NaN         NaN         NaN         NaN         NaN NaN
# 105       NaN         NaN         NaN         NaN         NaN NaN
#
#      adamw_weight_decay  w1  w2  batch_size COMMENT IN_FEATURES OUT_FEATURES  \
# 64                  NaN NaN NaN         NaN     NaN         NaN          NaN
# 75                  NaN NaN NaN         NaN     NaN         NaN          NaN
# 58                  NaN NaN NaN         NaN     NaN         NaN          NaN
# 12                  NaN NaN NaN         NaN     NaN         NaN          NaN
# 105                 NaN NaN NaN         NaN     NaN         NaN          NaN
#
#      SEED  EPOCHS  NUM_TRIALS  PATIENCE
# 64    NaN     NaN         NaN       NaN
# 75    NaN     NaN         NaN       NaN
# 58    NaN     NaN         NaN       NaN
# 12    NaN     NaN         NaN       NaN
# 105   NaN     NaN         NaN       NaN

# %%
df[::-1].head()
# Out:
#      num_outputs  input_dim  fc_dim  dropout  scale  \
# 106          NaN        NaN     NaN      NaN    NaN
# 105          2.0        6.0     NaN      0.7  256.0
# 104          2.0        6.0     NaN      0.7  256.0
# 103          2.0        6.0     NaN      0.7  256.0
# 102          2.0        6.0     NaN      0.7  256.0
#
#                           comment  seed  batch size   epochs  learning rate  \
# 106                           NaN   NaN         NaN      NaN            NaN
# 105  after scaling - large epochs  42.0        30.0  10000.0         0.0001
# 104                 after scaling  42.0        30.0   1500.0         0.0001
# 103       baseline before scaling  42.0        30.0   1500.0         0.0001
# 102       baseline before scaling  42.0        30.0    500.0         0.0001
#
#      weight decay                      input features output features  \
# 106           NaN                                 NaN             NaN
# 105          0.01  [beta, Av, F115, F150, F277, F444]          [flag]
# 104          0.01  [beta, Av, F115, F150, F277, F444]          [flag]
# 103          0.01  [beta, Av, F115, F150, F277, F444]          [flag]
# 102          0.01  [beta, Av, F115, F150, F277, F444]          [flag]
#
#      sample size       loss function  \
# 106          NaN                 NaN
# 105          NaN  CrossEntropyLoss()
# 104          NaN  CrossEntropyLoss()
# 103          NaN  CrossEntropyLoss()
# 102          NaN  CrossEntropyLoss()
#
#                                                  model  \
# 106                                                NaN
# 105  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 104  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 103  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 102  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
#
#                                              optimizer  num params  \
# 106                                              AdamW         NaN
# 105  AdamW (\nParameter Group 0\n    amsgrad: False...     19010.0
# 104  AdamW (\nParameter Group 0\n    amsgrad: False...     19010.0
# 103  AdamW (\nParameter Group 0\n    amsgrad: False...     19010.0
# 102  AdamW (\nParameter Group 0\n    amsgrad: False...     19010.0
#
#      purity (dusty)  completeness (dusty)  accuracy  \
# 106             NaN                   NaN       NaN
# 105        0.545455               0.75000  0.702128
# 104        0.511628               0.68750  0.670213
# 103        0.500000               0.65625  0.659574
# 102        0.448980               0.68750  0.606383
#
#                                       confusion matrix  last validation loss  \
# 106                                                NaN                   NaN
# 105  Predicted   0   1\nActual           \n0       ...              0.803179
# 104  Predicted   0   1\nActual           \n0       ...              0.784854
# 103  Predicted   0   1\nActual           \n0       ...              0.797382
# 102  Predicted   0   1\nActual           \n0       ...              0.809415
#
#      n_layers  n_units_l0  dropout_l0  n_units_l1  dropout_l1        lr  \
# 106       2.0        95.0    0.237303       124.0    0.433854  0.006805
# 105       NaN         NaN         NaN         NaN         NaN       NaN
# 104       NaN         NaN         NaN         NaN         NaN       NaN
# 103       NaN         NaN         NaN         NaN         NaN       NaN
# 102       NaN         NaN         NaN         NaN         NaN       NaN
#
#      adamw_weight_decay        w1        w2  batch_size  \
# 106            0.000061  1.462974  1.518061        16.0
# 105                 NaN       NaN       NaN         NaN
# 104                 NaN       NaN       NaN         NaN
# 103                 NaN       NaN       NaN         NaN
# 102                 NaN       NaN       NaN         NaN
#
#                            COMMENT                         IN_FEATURES  \
# 106  TEST LOGGING WITH OPTUNA CODE  [beta, Av, F115, F150, F277, F444]
# 105                            NaN                                 NaN
# 104                            NaN                                 NaN
# 103                            NaN                                 NaN
# 102                            NaN                                 NaN
#
#     OUT_FEATURES  SEED   EPOCHS  NUM_TRIALS  PATIENCE
# 106       [flag]  42.0  10000.0       100.0      30.0
# 105          NaN   NaN      NaN         NaN       NaN
# 104          NaN   NaN      NaN         NaN       NaN
# 103          NaN   NaN      NaN         NaN       NaN
# 102          NaN   NaN      NaN         NaN       NaN
