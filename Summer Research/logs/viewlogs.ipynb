# %%
from pathlib import Path
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
cwd = Path.cwd()

# %%
df = pd.read_json('fc_log.json')
df.columns
# Out:
# Index(['num_outputs', 'input_dim', 'fc_dim', 'dropout', 'scale', 'comment',
#        'seed', 'batch size', 'epochs', 'learning rate', 'weight decay',
#        'input features', 'output features', 'sample size', 'loss function',
#        'model', 'optimizer', 'num params', 'purity (dusty)',
#        'completeness (dusty)', 'accuracy', 'confusion matrix',
#        'last validation loss'],
#       dtype='str')

# %%
df.sort_values(by='accuracy', ascending=False).head()
# Out:
#     num_outputs  input_dim  fc_dim  dropout  scale           comment  seed  \
# 64            2        NaN     NaN      0.6     32  lower batch szie    42
# 58            2        NaN     NaN      0.6     32   actually dropna    42
# 12            2        1.0     NaN      0.2     16     add beta mask    42
# 60            2        NaN     NaN      0.4     32      less dropout    42
# 31            2        2.0     NaN      0.2      8   increase epochs    42
#
#     batch size  epochs  learning rate  weight decay  \
# 64          32    5000         0.0001          0.01
# 58         128    5000         0.0001          0.01
# 12         128    4000         0.0001          0.01
# 60         128    5000         0.0001          0.01
# 31         128   32000         0.0001          0.01
#
#                         input features output features  sample size  \
# 64  [beta, Av, F115, F150, F277, F444]          [flag]          449
# 58  [beta, Av, F115, F150, F277, F444]          [flag]          449
# 12                              [beta]          [flag]          481
# 60  [beta, Av, F115, F150, F277, F444]          [flag]          449
# 31                          [beta, Av]          [flag]          481
#
#          loss function                                              model  \
# 64  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 58  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 12  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 60  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 31  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
#
#                                             optimizer  num params  \
# 64  AdamW (\nParameter Group 0\n    amsgrad: False...       25298
# 58  AdamW (\nParameter Group 0\n    amsgrad: False...       25298
# 12  AdamW (\nParameter Group 0\n    amsgrad: False...         270
# 60  AdamW (\nParameter Group 0\n    amsgrad: False...       25298
# 31  AdamW (\nParameter Group 0\n    amsgrad: False...         286
#
#     purity (dusty)  completeness (dusty)  accuracy  \
# 64        0.642857              0.580645  0.741573
# 58        0.575000              0.741935  0.719101
# 12        0.611111              0.343750  0.705263
# 60        0.566667              0.548387  0.696629
# 31        0.545455              0.562500  0.694737
#
#                                      confusion matrix  last validation loss
# 64  Predicted   0   1\nActual           \n0       ...              0.788367
# 58  Predicted   0   1\nActual           \n0       ...              0.782468
# 12  Predicted   0   1\nActual           \n0       ...              0.823392
# 60  Predicted   0   1\nActual           \n0       ...              0.838375
# 31  Predicted   0   1\nActual           \n0       ...              0.802310
