# %%
from pathlib import Path
import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
cwd = Path.cwd()

# %%
df = pd.read_json('fc_log.json')
df
# Out:
#     num_outputs  input_dim  fc_dim  dropout  scale  \
# 0             2          1   128.0      0.4     32
# 1             2          1   128.0      0.4     32
# 2             2          1   128.0      0.4     32
# 3             2          1   128.0      0.4     32
# 4             2          1   128.0      0.4     32
# 5             2          1   128.0      0.4     32
# 6             2          1   128.0      0.4     32
# 7             2          1    32.0      0.4     32
# 8             2          1    16.0      0.4     32
# 9             2          1     NaN      0.2      8
# 10            2          1     NaN      0.2      8
# 11            2          1     NaN      0.2     16
#
#                                        comment  seed  batch size  epochs  \
# 0                                         test    42          64    1000
# 1                                         test    42          64    1000
# 2                               batch size 128    42         128    1000
# 3                               batch size 256    42         256    1000
# 4                                batch size 16    42          16    1000
# 5                                         test    42         128    1000
# 6                           incrase num epochs    42         128    2000
# 7                          decrease model size    42         128    2000
# 8                                                 42         128    2000
# 9                            reduce model size    42         128    2000
# 10                                                42         128    4000
# 11  increase model size - only predicted flase    42         128    4000
#
#     learning rate  weight decay input features output features  sample size  \
# 0          0.0001          0.01         [beta]          [flag]          486
# 1          0.0001          0.01         [beta]          [flag]          486
# 2          0.0001          0.01         [beta]          [flag]          486
# 3          0.0001          0.01         [beta]          [flag]          486
# 4          0.0001          0.01         [beta]          [flag]          486
# 5          0.0001          0.01         [beta]          [flag]          486
# 6          0.0001          0.01         [beta]          [flag]          486
# 7          0.0001          0.01         [beta]          [flag]          486
# 8          0.0001          0.01         [beta]          [flag]          486
# 9          0.0001          0.01         [beta]          [flag]          486
# 10         0.0001          0.01         [beta]          [flag]          486
# 11         0.0001          0.01         [beta]          [flag]          486
#
#          loss function                                              model  \
# 0   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 1   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 2   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 3   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 4   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 5   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 6   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 7   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 8   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 9   CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 10  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
# 11  CrossEntropyLoss()  GalaxyClassifier(\n  (fc): FCBlock(\n    (bloc...
#
#                                             optimizer  num params  \
# 0   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 1   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 2   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 3   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 4   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 5   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 6   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 7   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 8   AdamW (\nParameter Group 0\n    amsgrad: False...         858
# 9   AdamW (\nParameter Group 0\n    amsgrad: False...          96
# 10  AdamW (\nParameter Group 0\n    amsgrad: False...          96
# 11  AdamW (\nParameter Group 0\n    amsgrad: False...         270
#
#     purity (dusty)  completeness (dusty)  accuracy  \
# 0         0.425532               0.62500  0.593750
# 1         0.425532               0.62500  0.593750
# 2         0.434783               0.62500  0.604167
# 3         0.431373               0.68750  0.593750
# 4         0.333333               0.03125  0.656250
# 5         0.434783               0.62500  0.604167
# 6         0.583333               0.21875  0.687500
# 7         0.583333               0.21875  0.687500
# 8         0.583333               0.21875  0.687500
# 9              NaN                   NaN  0.666667
# 10             NaN                   NaN  0.666667
# 11        1.000000               0.03125  0.677083
#
#                                      confusion matrix  last validation loss
# 0   Predicted   0   1\nActual           \n0       ...              0.830167
# 1   Predicted   0   1\nActual           \n0       ...              0.830167
# 2   Predicted   0   1\nActual           \n0       ...              0.830733
# 3   Predicted   0   1\nActual           \n0       ...              0.826692
# 4   Predicted   0  1\nActual          \n0         ...              0.831327
# 5   Predicted   0   1\nActual           \n0       ...              0.830733
# 6   Predicted   0  1\nActual          \n0         ...              0.831628
# 7   Predicted   0  1\nActual          \n0         ...              0.831628
# 8   Predicted   0  1\nActual          \n0         ...              0.831628
# 9   Predicted   0\nActual       \n0          64\n1...              0.834341
# 10  Predicted   0\nActual       \n0          64\n1...              0.832097
# 11  Predicted   0  1\nActual          \n0         ...              0.829949
