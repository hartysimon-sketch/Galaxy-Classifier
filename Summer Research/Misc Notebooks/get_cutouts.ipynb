# %%
from pathlib import Path
import utils as ut
import matplotlib.pyplot as plt
import matplotlib

import pandas as pd
pd.set_option('display.max_columns', None)

from astropy.io import fits
from astropy.nddata import Cutout2D
from astropy.coordinates import SkyCoord
import astropy.units as u
from astropy.wcs import WCS

# %%
CUT = True
MASK = False

# %%
cwd = Path.cwd()
table_dir = cwd / 'data' / 'tables'
all_dir =  cwd / 'data' / 'tables_all'
mosaic_dir = cwd / 'data' / 'mosaics'
cutout_dir = cwd / 'data' / 'cutouts'
masked = cwd / 'data' / 'masked_cuts'

# %%
table_dfs = {}
# all_dfs = {}
for file in table_dir.iterdir():
    table_dfs[file.stem] = pd.read_csv(file).sort_values(by="RA")
# for file in all_dir.iterdir():
#    all_dfs[file.stem] = pd.read_csv(file).sort_values(by="RA")

headers = ut.fits_df(mosaic_dir)
headers = headers[['FILENAME'] + [col for col in headers.columns if col != 'FILENAME']]

# %%
table_dfs['ceers'].head()
# Out:
#        ID  CATID          RA        DEC  FIELD  KRON_RADIUS  A_IMAGE  B_IMAGE  \
# 31  33146   1111  214.707443  52.752602      4          1.6    6.768    5.640
# 33  34063   2068  214.710880  52.749456      4          1.6   12.687   10.301
# 34  34143   2152  214.713800  52.751571      4          1.6    5.493    5.073
# 32  33819   1810  214.730439  52.764594      4          1.6    8.133    7.336
# 38  38028   6402  214.733892  52.744447      4          1.6    7.291    6.162
#
#     THETA_IMAGE  RH_F200W  FWHM_F200W    FLUX_115  FLUXERR_115     FLUX_150  \
# 31         1.73     2.679        3.74  237.465723     7.216802   726.660516
# 33       -66.75     4.910        4.45  664.059615    15.499639  2428.506258
# 34        45.43     2.551        3.54  359.536911     6.640979  1480.254921
# 32        41.85     4.408        5.23  325.902345     8.611434   990.314548
# 38        63.08     5.311       10.80   97.215251     6.048687   310.144905
#
#     FLUXERR_150     FLUX_200  FLUXERR_200     FLUX_277  FLUXERR_277  \
# 31    12.946670  1844.699034    18.449695  2470.093865    13.383183
# 33    29.638459  4897.578343    38.912522  6269.425196    31.987811
# 34    13.301023  2510.333386    18.358585  3141.374008    11.774955
# 32    12.743932  1787.489533    15.236158  2987.870067    14.460071
# 38     8.581192   668.445122     7.360632  1374.656289     7.353075
#
#        FLUX_356  FLUXERR_356     FLUX_410  FLUXERR_410     FLUX_444  \
# 31  2816.058145    11.657201  3276.228096    18.652190  3360.251942
# 33  7709.425618    31.986032  9068.378745    50.135627  9243.324765
# 34  3781.125624    11.565237  4302.263764    17.718505  4499.960241
# 32  4564.074987    16.106063  5307.517901    25.123813  5694.947422
# 38  2138.435994     9.004210  2853.090274    16.921567  3127.997867
#
#     FLUXERR_444   FLUX_606  FLUXERR_606    FLUX_814  FLUXERR_814  FLUX_105  \
# 31    12.265147  53.948621    21.874359   83.739469    71.583734       0.0
# 33    36.566652  82.444267    43.163514  325.357686   130.584762       0.0
# 34    11.773987  16.829451    21.836852   79.629050    55.660086       0.0
# 32    18.677295  32.115466    28.812730   50.713380    61.665940       0.0
# 38    11.024293  16.604338    26.411253   36.361524    74.071369       0.0
#
#      FLUXERR_105    FLUX_125  FLUXERR_125     FLUX_140  FLUXERR_140  \
# 31  2.130000e+13  289.444577    22.064209   377.890589    17.662729
# 33  4.420000e+13  794.760392    42.890028  1512.254997    35.844918
# 34  1.710000e+13  460.964042    17.470939   872.991190    16.412959
# 32  2.890000e+13  428.400896    35.757922   670.958439    16.099216
# 38  2.640000e+13  119.106905    26.519588   173.297100    16.299365
#
#        FLUX_160  FLUXERR_160   c_Hmag  c_zbest  c_zspec  c_mass  c_sfrtot  \
# 31   730.276117    57.706112  23.9069    2.755     -1.0   10.48   46.1575
# 33  2507.915108   118.862167  22.9228    2.659     -1.0   10.97   32.4312
# 34  1488.164881    47.265645  23.4973    2.481     -1.0   10.75   11.8211
# 32   962.826981    83.623815  23.8455    2.183     -1.0   10.58   72.9721
# 38   299.048614    79.894651  24.7154    2.298     -1.0   10.34    5.9758
#
#           c_U        c_V        c_J  c_gf_phy_re_h  c_zhu_sig1  \
# 31 -20.978614 -22.214724 -22.794259       1.725984     -99.000
# 33 -21.404140 -23.009850 -23.781615       2.417378     -99.000
# 34 -20.446645 -22.207668 -22.903712       0.485851       9.909
# 32 -19.584302 -21.324106 -22.820195       1.965939       9.780
# 38 -18.790996 -20.434395 -22.188500       2.773791       8.874
#
#     c_ACS_F606W_FLUX  c_ACS_F606W_FLUXERR  c_ACS_F814W_FLUX  \
# 31        295.423317            28.962552        412.110703
# 33        131.892269            30.029407        288.778162
# 34         10.892425            17.217352         65.004302
# 32         30.734267            21.582882         79.836028
# 38         29.973669            24.041002         51.601839
#
#     c_ACS_F814W_FLUXERR  c_WFC3_F140W_FLUX  c_WFC3_F140W_FLUXERR  \
# 31            66.519244         642.369671             51.374166
# 33            66.305593        1397.074250             71.254182
# 34            35.500375         886.870566             45.051550
# 32            30.675006         771.904919             38.153568
# 38            43.253673         269.083875             45.126921
#
#     c_WFC3_F125W_FLUX  c_WFC3_F125W_FLUXERR  c_WFC3_F160W_FLUX  \
# 31         500.958359             30.959484         993.710206
# 33         723.153649             39.277954        2459.677670
# 34         457.378479             25.980616        1449.043220
# 32         501.449833             34.668454        1051.520980
# 38         171.626744             33.935802         471.896137
#
#     c_WFC3_F160W_FLUXERR    sepmos       Kmag       m_zspec  m_zspec_zqual  \
# 31             43.754539  0.145525  23.235186  1.000000e+20         999999
# 33             53.050190  0.014241  22.175047  1.000000e+20         999999
# 34             34.518741  0.009454  22.900672  1.000000e+20         999999
# 32             44.259033  0.030158  23.269391  1.000000e+20         999999
# 38             47.455343  0.015752  24.337336  1.000000e+20         999999
#
#      m_zspec_use   id_2          ra        dec  z_spec  nusefilt      z_ml  \
# 31  1.000000e+20  33146  214.707443  52.752602    -1.0        12  3.084017
# 33  1.000000e+20  34063  214.710880  52.749456    -1.0        12  2.774182
# 34  1.000000e+20  34143  214.713800  52.751571    -1.0        12  2.583029
# 32  1.000000e+20  33819  214.730439  52.764594    -1.0        12  2.588060
# 38  1.000000e+20  38028  214.733892  52.744447    -1.0        12  2.854842
#
#     z_ml_chi2  z_ml_risk    z_phot  z_phot_chi2  z_phot_risk  z_min_risk  \
# 31  34.821747   0.003151  3.084017    34.821747     0.003151    3.054999
# 33  54.904960   0.005959  2.774182    54.904960     0.005959    2.780856
# 34  83.117220   0.004027  2.583029    83.117220     0.004027    2.596461
# 32   5.953066   0.011277  2.588060     5.953066     0.011277    2.560676
# 38   4.600480   0.069454  2.854842     4.600480     0.069454    2.780856
#
#     min_risk  z_raw_chi2   raw_chi2      z025      z160      z500      z840  \
# 31  0.003881    3.095752  34.854088  3.002157  3.037774  3.081846  3.110119
# 33  0.006166    2.780856  54.940250  2.683268  2.730388  2.772166  2.816012
# 34  0.004566    2.596461  83.378190  2.518667  2.549198  2.584029  2.619569
# 32  0.011588    2.596461   6.047738  2.342645  2.555176  2.589994  2.614751
# 38  0.053690    2.857234   4.591600  2.367505  2.629962  2.802556  2.883880
#
#         z975       restU  restU_err      restB  restB_err       restV  \
# 31  3.130095   593.86300  10.342834  1488.7198  35.912780  2145.54860
# 33  2.860761  1310.32620  28.588806  3423.4740  97.941284  5179.58540
# 34  2.652335   580.73640  11.403748  1674.8430  32.843628  2460.17900
# 32  2.630196   532.24170  29.102036  1121.1001  31.443298  1736.71010
# 38  2.932878   189.02893   7.647407   476.8194  18.084885   757.08734
#
#     restV_err      restJ  restJ_err           dL            Lv          mass  \
# 31  59.560790  3573.2024  199.60022  26275.34923  6.202666e+10  4.964837e+10
# 33  97.876465  9503.7920  122.22412  23129.57297  1.260000e+11  1.200000e+11
# 34  30.812012  4556.4480   49.53662  21216.39252  5.285547e+10  5.485311e+10
# 32  52.726562  5735.8516  200.31445  21266.45095  3.743589e+10  3.409528e+10
# 38  49.127014  3460.3623  273.66602  23943.41049  1.925493e+10  2.225169e+10
#
#           sfr           LIR  energy_abs        Av  lw_age_V       MLv  \
# 31   0.121345  7.815966e+09           0  0.276545       -99  0.800436
# 33   0.239086  1.672777e+10           0  0.325681       -99  0.953431
# 34   0.097318  6.572670e+09           0  0.191380       -99  1.037794
# 32  46.270398  3.050000e+11           0  1.516130       -99  0.910765
# 38   7.779807  6.392164e+10           0  2.047237       -99  1.155636
#
#           UV        VJ      lmass  ZA_finkelstein  ZPEAK_finkelstein  \
# 31  1.394630  0.553798  10.695905            3.10           3.101271
# 33  1.492289  0.659005  11.078127            2.86           2.806846
# 34  1.567469  0.669149  10.739201            2.65           2.633865
# 32  1.284046  1.297176  10.532694            2.32           2.426945
# 38  1.506544  1.649939  10.347363            2.92           2.737428
#
#         fullname fullname_v02     id  fast_z  fast_ltau  fast_metal  \
# 31  nircam4-1111   nircam4--1  33146    3.08        8.3        0.02
# 33  nircam4-2068   nircam4--1  34063    2.77        8.3        0.02
# 34  nircam4-2152   nircam4--1  34143    2.58        8.3        0.02
# 32  nircam4-1810   nircam4--1  33819    2.59        8.7        0.02
# 38  nircam4-6402   nircam4--1  38028    2.85        8.5        0.02
#
#     fast_lage  fast_Av  fast_lmass  fast_lsfr  fast_lssfr  fast_la2t  \
# 31        9.0      0.1       10.51       0.25      -10.26        0.7
# 33        8.9      0.6       10.88       1.06       -9.82        0.6
# 34        8.9      0.6       10.50       0.68       -9.82        0.6
# 32        8.8      1.7       10.59       1.67       -8.93        0.1
# 38        8.6      2.2       10.40       1.66       -8.74        0.1
#
#     fast_chi2  with_miri     excess  flag  F115W_MAG  F115W_MAG_ERR  \
# 31      30.30          0   1.378446     0   -99.0000       -99.0000
# 33      52.20          0   7.594937     0    24.1917         0.0241
# 34     102.00          0   9.732360     0    24.9950         0.0124
# 32       6.89          1  17.264276     1    24.7730         0.0103
# 38      31.50          1  16.061185     1    26.2653         0.0459
#
#      F115W_RE  F115W_RE_ERR  F115W_N  F115W_N_ERR  F115W_Q  F115W_Q_ERR  \
# 31 -99.000000    -99.000000 -99.0000       0.0000 -99.0000     -99.0000
# 33   0.254490      0.011925   4.7082       0.1422   0.8581       0.0089
# 34   0.056985      0.001122   3.5623       0.1668   0.7491       0.0143
# 32   0.332274      0.006546   5.4744       0.0581   0.6210       0.0013
# 38   0.323892      0.022722   1.2197       0.1109   0.4893       0.0261
#
#      F115W_PA  F115W_PA_ERR  F115W_FLAG  F150W_MAG  F150W_MAG_ERR  F150W_RE  \
# 31 -99.000000      -99.0000           3    24.2829         0.0152  0.049548
# 33  32.129204        2.9517           0    22.7745            NaN  0.251337
# 34 -86.380700        2.0886           0    23.4421         0.0034  0.055125
# 32 -15.633099        0.0045           0    23.8125         0.0027  0.187614
# 38 -68.293304        2.9533           0    24.8247         0.0232  0.330939
#
#     F150W_RE_ERR  F150W_N  F150W_N_ERR  F150W_Q  F150W_Q_ERR   F150W_PA  \
# 31      0.001392   6.4452       0.2581   0.8743       0.0141 -37.046600
# 33           NaN   5.7366          NaN   0.8796          NaN  17.206398
# 34      0.000393   3.6662       0.0619   0.7172       0.0050 -79.513400
# 32      0.000915   4.2531       0.0159   0.7464       0.0016 -14.081600
# 38      0.011178   1.3865       0.0471   0.6951       0.0148 -81.414100
#
#     F150W_PA_ERR  F150W_FLAG  F200W_MAG  F200W_MAG_ERR   F200W_RE  \
# 31        3.9170           0    23.2549         0.0035   0.045585
# 33           NaN           0   -99.0000       -99.0000 -99.000000
# 34        0.6519           0    22.8439         0.0002   0.052611
# 32        0.0036           0   -99.0000       -99.0000 -99.000000
# 38        2.2411           0    24.1421         0.0097   0.269985
#
#     F200W_RE_ERR  F200W_N  F200W_N_ERR  F200W_Q  F200W_Q_ERR  F200W_PA  \
# 31      0.000276   5.7695       0.0532   0.8627       0.0005  -48.2545
# 33    -99.000000 -99.0000       0.0000 -99.0000     -99.0000  -99.0000
# 34      0.000018   4.3773       0.0035   0.6958       0.0000  -83.3743
# 32    -99.000000 -99.0000       0.0000 -99.0000     -99.0000  -99.0000
# 38      0.004011   1.4982       0.0235   0.6996       0.0068  -78.0599
#
#     F200W_PA_ERR  F200W_FLAG  F277W_MAG  F277W_MAG_ERR  F277W_RE  \
# 31        0.1077           0    22.8202         0.0007  0.048825
# 33      -99.0000           3    21.7069         0.0029  0.252492
# 34        0.0007           0    22.6394         0.0009  0.049419
# 32      -99.0000           3    22.6077         0.0025  0.161034
# 38        1.0090           0    23.5581         0.0026  0.195297
#
#     F277W_RE_ERR  F277W_N  F277W_N_ERR  F277W_Q  F277W_Q_ERR   F277W_PA  \
# 31      0.000051   8.0000       0.0201   0.9305       0.0001 -82.083600
# 33      0.001767   8.0000       0.0434   0.8499       0.0016  -2.029999
# 34      0.000147   3.8036       0.0307   0.6944       0.0020 -80.320900
# 32      0.000807   4.4359       0.0286   0.8772       0.0024 -49.309500
# 38      0.000873   1.5061       0.0103   0.6910       0.0026 -79.801800
#
#     F277W_PA_ERR  F277W_FLAG  F356W_MAG  F356W_MAG_ERR   F356W_RE  \
# 31        0.0116           0    22.7747         0.0000   0.046305
# 33        0.3478           0   -99.0000       -99.0000 -99.000000
# 34        0.2614           0    22.4181         0.0009   0.050586
# 32        0.6503           0    22.2486         0.0013   0.129690
# 38        0.3637           0    23.1452         0.0016   0.165651
#
#     F356W_RE_ERR  F356W_N  F356W_N_ERR  F356W_Q  F356W_Q_ERR   F356W_PA  \
# 31      0.000000   5.4071       0.0015   0.8775       0.0000 -75.874200
# 33    -99.000000 -99.0000       0.0000 -99.0000     -99.0000 -99.000000
# 34      0.000138   4.1874       0.0307   0.6954       0.0020 -83.236694
# 32      0.000282   3.5924       0.0174   0.8771       0.0018 -46.182602
# 38      0.000471   1.6451       0.0084   0.6730       0.0019 -79.434500
#
#     F356W_PA_ERR  F356W_FLAG  F444W_MAG  F444W_MAG_ERR  F444W_RE  \
# 31        0.0001           0    22.6064         0.0004  0.039633
# 33      -99.0000           3    21.4074         0.0009  0.168039
# 34        0.2364           0    22.2646         0.0010  0.047874
# 32        0.4837           0    22.0435         0.0017  0.117564
# 38        0.2370           0    22.7981         0.0017  0.143385
#
#     F444W_RE_ERR  F444W_N  F444W_N_ERR  F444W_Q  F444W_Q_ERR   F444W_PA  \
# 31      0.000015   5.7217       0.0106   0.9317       0.0001 -68.124600
# 33      0.000357   8.0000       0.0149   0.8361       0.0000  -2.036202
# 34      0.000150   3.7229       0.0364   0.6874       0.0024 -78.820100
# 32      0.000303   3.5881       0.0236   0.8697       0.0022 -47.433900
# 38      0.000408   1.6757       0.0110   0.6679       0.0022 -78.034400
#
#     F444W_PA_ERR  F444W_FLAG  lgSigma1  nSigma1    beta  beta_dark    lmass_p
# 31        0.0142           0     10.10    0.765 -0.7180 -99.000000  10.753523
# 33        0.0040           0     10.20    0.445 -0.0587 -99.000000  11.188819
# 34        0.2958           0     10.10    0.764  1.2900 -99.000000  10.822574
# 32        0.5913           0      9.75    0.518  0.3590   0.372796  10.890815
# 38        0.2649           0      9.51    0.453  1.7400   0.662355  11.289636

# %%
if CUT: 
    with_two = []
    size = 2

    stamp = u.Quantity([size, size], u.arcsec)

    for _, row in headers.iterrows():
        path = row['FILEPATH']
        catalogs = [('ceers', 'ceers'),
                    ('cosmos', 'primer_cosmos'),
                    ('uds', 'primer_uds')]
        bands = ['f150w', 'f277w', 'f444w']

        band = None
        catalog = None

        for cat, b in zip(catalogs, bands):
            if cat[0] in path.name:
                catalog = cat[1]
            if b in path.name:
                band = b

        table = table_dfs[catalog]
        # all_table = all_dfs[catalog + '_all']

        hdul = fits.open(path)
        data = hdul[0].data
        wcs = WCS(hdul[0].header)

        for _, row in table.iterrows():

            arcsecs = ((size/2) * u.arcsec)
            ra = row['RA'] * u.deg
            dec = row['DEC'] * u.deg
            # ramask = (all_table['RA'] < (ra + arcsecs).value) & (all_table['RA'] > (ra - arcsecs).value)
            # decmask = (all_table['DEC'] < (dec + arcsecs).value) & (all_table['DEC'] > (dec - arcsecs).value)
            # num_objs = len(all_table[ramask & decmask])
            # if num_objs > 1:
            #     print(num_objs, ra.value)

            pos = SkyCoord(ra, dec, frame="icrs")
            cutout = Cutout2D(data, pos, stamp, wcs=wcs)

            header = cutout.wcs.to_header()
            # header['NUMOBJS'] = num_objs
            for col_name, value in row.items():
                if pd.isna(value):
                    continue
                key = str(col_name)[:8].upper()
                header[key] = value
            header['BAND'] = band
            header['CATALOG'] = catalog

            folder = Path(cutout_dir / f"{float(row['RA'])}")
            folder.mkdir(parents=True, exist_ok=True)

            if MASK:
                cutout.data = ut.mask_other_sources(cutout.data, nsigma=3)[0]

            cutout_fits = fits.PrimaryHDU(data=cutout.data, header=header)
            cutout_fits.writeto(folder / f"{band}.fits", overwrite=True)

        hdul.close()

    size = len(list(cutout_dir.glob('*')))
    print(f"Number of cutouts: {size}")
    print("Expected: 486")

    num_bands = 3

    for folder in cutout_dir.iterdir():
        if folder.is_dir():
            count = len(list(folder.glob('*')))
            if count != num_bands:
                print(f"{folder.name}")
# Out:
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-06-21T20:33:17.584' from MJD-BEG.
# Set DATE-AVG to '2022-09-21T10:17:11.746' from MJD-AVG.
# Set DATE-END to '2022-12-22T05:42:36.326' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -74.811810 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -36.758463 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1725319218.494 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-06-21T18:09:46.713' from MJD-BEG.
# Set DATE-AVG to '2022-09-22T03:18:18.036' from MJD-AVG.
# Set DATE-END to '2022-12-25T03:57:18.887' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -74.839696 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -36.739053 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1725216481.136 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'datfix' made the change 'Set DATE-BEG to '2022-06-21T21:46:07.469' from MJD-BEG.
# Set DATE-AVG to '2022-10-07T06:02:04.794' from MJD-AVG.
# Set DATE-END to '2022-12-22T06:44:09.762' from MJD-END'. [astropy.wcs.wcs]
# WARNING: FITSFixedWarning: 'obsfix' made the change 'Set OBSGEO-L to   -74.796897 from OBSGEO-[XYZ].
# Set OBSGEO-B to   -36.768884 from OBSGEO-[XYZ].
# Set OBSGEO-H to 1725373838.960 from OBSGEO-[XYZ]'. [astropy.wcs.wcs]
# Number of cutouts: 486
# Expected: 486
